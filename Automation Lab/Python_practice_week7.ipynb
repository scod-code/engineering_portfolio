# %% [markdown]
# #Building Regression Model
#
#
#
#
# 1.   Data Explore Analysis
#
# * Get general information : Shape, Data Types, Missing values, outliers, distribution, etc.
#
# * Handling missing values, outliers
#
# * Create visualizations and interpret them
#
# 2.   Prepare data for analysis
# *   Split data with ratio 70-30 (training-testing)
# *   Print out the shape of your splited data
#
# 3.   Modelling
#
#
#
# *   3.1/ Simple linear for **Radio vs Sale**, **Newspaper vs Sale**. Fit the Model, write the regression formular and plot the models ( give comment about the relationship between depedent variables and independent variable)
# *   3.2/ Multiple linear for **TV, Radio, Newspaper vs Sale**. Fit the Model, write the regression formular. Base on your regression formular, give your comments about the relationship between depedent variables and independent variable base on the coefficients, confirm it with the relationship in 3.1
