# %% [markdown]
# #Question 1
#
# **what is the data type of these**
#
# 1. Shoe size: 5, 6, 7, 8, 9
# 2. Number of pets owned: 0, 1, 1, 3, 2, 4
# 3. Monthly salary (in $): 2,500, 3,000, 4,500, 5,000
# 4. Rating of a restaurant: Poor, Fair, Good, Excellent
# 5. Days of the week: Monday, Tuesday, Wednesday, Thursday
# 6. Weight of apples (in kg): 1.2, 1.5, 1.8, 2.0
# 7. Temperature (in °C) over a week: 22, 24, 26, 28, 30, 21, 20
# 8. Time of a day : 0-2, 2-4, ..., 22-24.
# 9. Education level: High School, Bachelor’s, Master’s, PhD
# 10. GPA range:0-10, 11-20, 21-30, 31-40, 41-50, 51-60, 61-70, 71-80, 81-90, 91-100

# %% [markdown]
# # Question2
#
# **Perform EDA with the Titanic Data**
#
# 1. Feature classifications
# 2. Detect and handling missing values
# 3. Detect and handling outliers
# 4. Create visualizations (at least 5 plots) and give at least 1 comment about each plot
# 5. Feature selection: Base on your opinion, which features should be removed and why?
