# %% [markdown]
# #Question 1
#
# Write the code again and fill the blank for the code and answer
#
#
#
# *   What is the class in this question?
# *   What is the objects in this question?
#
# *   What is the attributes in this question?
# *   What is the methods in this question?

# %% [markdown]
# ![Screenshot 2024-11-07 at 10.33.45 AM.png](data:image/png;base64,...)

# %% [markdown]
# #Question 2
#
# Convert the following code into an equivalent class structure:
#
#
#
# *   Create a Rectangle class with length and width attributes.
# *   Add calculate_area and calculate_perimeter methods to use these attributes instead of parameters.
#
# **Answer these questions**
# *   What is the class in this question?
# *   What is the objects in this question?
#
# *   What is the attributes in this question?
# *   What is the methods in this question?

# %%
def calculate_area(length, width):
    area = length * width
    print(f"The area of the rectangle is {area}.")

def calculate_perimeter(length, width):
    perimeter = 2 * (length + width)
    print(f"The perimeter of the rectangle is {perimeter}.")

calculate_area(10, 5)
calculate_perimeter(10, 5)
# Out:
# The area of the rectangle is 50.
# The perimeter of the rectangle is 30.

# %% [markdown]
# #Question 3
#
# **Interest calculation**
#
# Intructions
#
# *   Create a BankAccount class with an __init__ method to initialize principal, rate, and time.
#
# *   Add a calculate_interest method to calculate the interest based on these values.
# *   Add a display_balance method that calls calculate_interest and displays the total balance.
#
# Hint:
#
# * interest = principal * (rate / 100) * time
# * total_balance = principal + interest
#
#
#
#
# **Answer these questions**
# *   What is the class in this question?
# *   What is the objects in this question?
#
# *   What is the attributes in this question?
# *   What is the methods in this question?
