# %% [markdown]
# #Question 1 :Classification for Wine Quality data
#
# **1.1**: Data Explore Analysis
#
#
# *   General information: Shape, Data type, basic stats
#
# *   Identiy feature: numerical or categical
# *   Missing values, outliers
#
#
# *   Visualization
#
# **1.2** Choose input and output (quality)
#
# **1.3** Split data with ratio 70-30
#
# **1.4** Perform Decision Tree with max depth =3  and plot a tree
#
# **1.5** Use a text cell,in three sentences, explain how the tree ( from the top to bottom) can classify out put

# %% [markdown]
# #Question 2: Clustering for Wine Quality
#
# **2.1** Scaled the data given below
#
# **2.2** Perform K-mean clustering with 3 cluster
#
# **2.3** Plot alcohol vs volatile acidity, alcohol vs sulphates, 3 clusters with different colors
#
# **2.4** Use a text cell, give comments about each plot, which variable does a better job in seperating cluster

# %%
#Chosen columns for clustering
clustering_data = data[['alcohol', 'volatile acidity', 'sulphates']]
