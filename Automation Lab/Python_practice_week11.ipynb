# %% [markdown]
# #Question 1 : Rewrite the code and fill-in the blank then answer
#
#
#
# *   What are class attributes and methods? What they do?
# *   What are instance attributes and methods? What they do?

# %% [markdown]
# ![Screenshot 2024-11-12 at 10.21.50 AM.png](data:image/png;base64,...)

# %% [markdown]
# #Question 2
#
#
#
# * Create a class ElectricCar that inherits from the Car class and adds a new attribute, battery_capacity, to store the battery size in kWh.
#
# * In the ElectricCar class, directly call the Car class’s __init__ method to initialize the inherited attributes make and year.
#
# * Add a method display_battery_info to ElectricCar that prints out the car’s battery capacity, and test this method by creating an instance of ElectricCar.

# %% [markdown]
# #Question 3 : Fill the blank to complete the pseudocode
#
# # This pseudocode defines a Car class and an ElectricCar subclass to model cars.
# # The Car class includes basic attributes like make and year, along with methods
# # to display car information and manage a class-level total car count.
# # The ElectricCar subclass adds a battery capacity attribute and a method to display battery information.
#
# BEGIN
#     # Define a Car class with basic attributes and methods
#     DEFINE CLASS Car
#         - CLASS ATTRIBUTE:
#             - total_cars = 0  # Shared by all Car instances
#
#         - METHOD: Initialize (make, year) ... # Please comment for clarity
#             - SET the car's make to the given make
#             - SET the car's year to the given year
#
#         - METHOD: Display Information ... # Please comment for clarity
#             - PRINT ...
#
#         - CLASS METHOD: Set Total Cars (count) ... # Please comment for clarity
#             - SET ...
#
#         - CLASS METHOD: Display Total Cars ... # Please comment for clarity
#             - PRINT ...
#     END CLASS
#
#     # Define an ElectricCar class that inherits from Car and adds a battery attribute
#     DEFINE CLASS ElectricCar INHERITS Car
#         ... # Please comment for clarity
#     END CLASS
#
#
# END
