# %%
from google.colab import drive
drive.mount('/content/gdrive')
path = "/content/gdrive/MyDrive/Colab Notebooks/My_Data/Titanic-Dataset.csv"
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd

data = pd.read_csv(path)

#read the first 5 rows
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data['Parch'].unique()
# Out:
# array([0, 1, 2, 5, 3, 4, 6])

# %%
# drop missing value in Embarked
data = data.dropna(subset=['Embarked'])

# filling missing value for Age
data['Age'] = data['Age'].fillna(data['Age'].mean())

#drop column cabin
data.drop('Cabin', axis=1, inplace=True)

data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
missing_values_count = data.isnull().sum()
missing_values_count
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
X = data.drop(['PassengerId', 'Name','Ticket','Survived', 'Embarked'], axis=1)
y = data['Survived']

print(X.shape)
print(y.shape)
# Out:
# (889, 6)
# (889,)

# %%
X.head()
# Out:
#    Pclass     Sex   Age  SibSp  Parch     Fare
# 0       3    male  22.0      1      0   7.2500
# 1       1  female  38.0      1      0  71.2833
# 2       3  female  26.0      0      0   7.9250
# 3       1  female  35.0      1      0  53.1000
# 4       3    male  35.0      0      0   8.0500

# %%
#Convert Male and female to binary for modeling

X['Sex'] = X['Sex'].map({'male': 1, 'female': 0})
print(X.head())
# Out:
#    Pclass  Sex   Age  SibSp  Parch     Fare
# 0       3    1  22.0      1      0   7.2500
# 1       1    0  38.0      1      0  71.2833
# 2       3    0  26.0      0      0   7.9250
# 3       1    0  35.0      1      0  53.1000
# 4       3    1  35.0      0      0   8.0500

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %% [markdown]
# # Question 1
#
# **Perform a classification task for the Titanic Data** with the dependent variable (output y) is Survived Column. The task includes:
#
#
#
# *   Split data for training and testing, ratio 70-30
#
# *   Conduct a Decision Tree model, plot the tree
# *   Validate your model with confusion matrix, classification report , ROC, AUC curve
#
#
# # Question 2
#
# If you are required to build a regression model, what is your Independent variable (X) and dependent variable (Y) would be?
